# %%
import pandas as pd

df_1 = pd.read_csv('Data/file1.csv')
df_2 = pd.read_csv('Data/file2.csv')
df_3 = pd.read_csv('Data/file3.csv')

# %%
df_1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df_3
# Out:
#      Customer          ST GENDER             Education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %%
df_2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
df_2 = df_2[['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type', 'Vehicle Class', 'Total Claim Amount']]

# %%
df_3 = df_3.rename({"State": "ST", "Gender":"GENDER"}, axis=1)
df_3 = df_3[['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type', 'Vehicle Class', 'Total Claim Amount']]

# %%
dataframe_clients = pd.concat([df_1,df_2,df_3], axis=0)

# %%
##Replacing null values – Replace missing values with means of the column (for numerical columns). Pay attention that the Income feature for instance has 0s which is equivalent to null values. (We assume here that there is no such income with 0 as it refers to missing values)
Hint: numpy.nan is considered of float64 data type.

# %%
df.insert(4, "income_mean", 0)
ltv_mean = int(np.mean(df['income']))
print(ltv_mean)
df['income_mean'] = [it if it else ltv_mean for it in df['income']]
data = pd.DataFrame(data)
df['income_mean'] = df.fillna({'income_mean' : round(ltv_mean)})
df = df.drop(columns = ['income'],axis = 1)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df.insert(4, "income_mean", 0)
#       2 ltv_mean = int(np.mean(df['income']))
#       3 print(ltv_mean)
#
# NameError: name 'df' is not defined

# %%
##- Bucketing the data - Write a function to replace column "State" to different zones. California as West Region, Oregon as North West, and Washington as East, and Arizona and Nevada as Central
(Manualy)

# %%
df['number of open complaints'].unique()

df['gender'].unique() 

 
df['st'] = df['st'].replace(r'AZ', 'Arizona', regex=True)
df['st'] = df['st'].replace(r'WA', 'Washington', regex=True)
df['st'] = df['st'].replace(r'Californiafornia', 'California', regex=True)
df['gender'] = df['gender'].replace(r'Femal', 'F', regex=True)
df['gender'] = df['gender'].replace(r'female', 'F', regex=True)
df['gender'] = df['gender'].replace(r'Male', 'M', regex=True)


df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 df['number of open complaints'].unique()
#       3 df['gender'].unique()
#       6 df['st'] = df['st'].replace(r'AZ', 'Arizona', regex=True)
#
# NameError: name 'df' is not defined
